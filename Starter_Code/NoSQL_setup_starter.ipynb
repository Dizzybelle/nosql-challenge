# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establisments', 'establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('65a087033f04288420953e11'), 'FHRSID': 647177, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000041489', 'BusinessName': 'Wear Bay Bowls Club', 'BusinessType': 'Pub/bar/nightclub', 'BusinessTypeID': 7843, 'AddressLine1': 'Wear Bay Road', 'AddressLine2': 'Folkestone', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT19 6PY', 'Phone': '', 'RatingValue': 4, 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2014-03-31T00:00:00', 'LocalAuthorityCode': '188', 'LocalAuthorityName': 'Folkestone and Hythe', 'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk', 'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 1.196408, 'latitude': 51.086058}, 'RightToReply': '', 'Distance': 4591.821311183521, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_establisment = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_establisment)

# %%
# Check that the new restaurant was inserted
db.establisments.find({"Business Name":"Penang Flavours"})

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {}
fields = {'BusinessTypeID':1, 'BusinessType':1}
results = establishments.find(query, fields)
for result in results:
    pprint(result)
# Out:
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e12')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953e14')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e16')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e17')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e19')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e1a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e1c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e20')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e21')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e22')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e23')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e24')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e25')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e26')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e27')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e28')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e29')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e2a')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953e2b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e2c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e2d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e2e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e2f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e30')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e31')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953e32')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e33')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e34')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e35')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e36')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953e37')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e38')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e39')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953e3a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e3b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e3c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e3d')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e3e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e3f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e41')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e42')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e43')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e44')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e45')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953e47')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e48')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e49')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e4a')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953e4b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e4d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e4e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e4f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e50')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953e51')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e52')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e53')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e55')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e56')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953e57')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e59')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e5a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e5c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e5d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e5e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e5f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e60')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e61')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e63')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e64')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e65')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e66')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e67')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e68')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e69')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e6a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e6b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e6c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e6d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e6e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e6f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e70')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e72')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e78')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e79')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953e7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e7b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e7c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e7d')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('65a087033f04288420953e7e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e7f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e80')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e81')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e82')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e83')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e84')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953e85')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e86')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e87')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e88')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('65a087033f04288420953e89')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e8a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e8b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e8c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e8d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e8e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e8f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e90')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e91')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e92')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e93')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e94')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e95')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e97')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953e98')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e99')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953e9a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e9b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e9c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e9d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953e9e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953e9f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ea0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ea1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ea2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ea3')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ea4')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ea5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ea6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ea7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ea8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ea9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eaa')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eab')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953eac')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ead')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eae')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eaf')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eb0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eb1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eb2')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953eb3')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953eb4')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953eb7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eb8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eb9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eba')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ebb')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953ebc')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ebd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ebe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ebf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ec0')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ec1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ec2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ec4')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953ec5')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953ec6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ec7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ec8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ec9')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953eca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ecb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ecc')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ecd')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ece')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ecf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ed1')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ed2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ed3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ed4')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ed5')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953ed6')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953ed7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ed8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ed9')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953eda')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953edb')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953edc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953edd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ede')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953edf')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ee0')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953ee1')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953ee2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ee3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ee4')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ee5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ee6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ee7')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953ee8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ee9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eea')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eeb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eec')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953eed')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953eee')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953eef')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ef0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ef1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ef2')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953ef3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ef4')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ef5')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ef6')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953ef7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953ef8')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953ef9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953efa')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953efb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953efc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953efd')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953efe')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953eff')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f00')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f01')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f02')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f03')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f04')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f05')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f06')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f07')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f08')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f09')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953f0a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f0b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f0c')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953f0d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f0e')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f0f')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f10')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f11')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f12')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f13')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f14')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f15')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f16')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f17')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f18')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f19')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f1a')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f1b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f1c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f1d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f1e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f1f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f20')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f21')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f23')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f24')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f25')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f26')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f27')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f28')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f29')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f2a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f2b')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f2c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f2d')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f2e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f2f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f30')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f31')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f32')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f33')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f34')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953f35')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f36')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f37')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f38')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f39')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f3a')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f3b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f3c')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953f3d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f3e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f3f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f40')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f41')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f42')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f43')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f44')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f46')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f47')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f49')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f4a')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f4b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f4c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f4d')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f4e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f4f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f50')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087033f04288420953f51')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f52')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f53')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f54')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f55')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f56')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f57')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f58')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f59')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953f5a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f5b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f5c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f5f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f60')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f61')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f62')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f63')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f64')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f65')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f66')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f67')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f68')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f6a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f6c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f71')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f72')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f73')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f74')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f75')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f76')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f78')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f79')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f7a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f7b')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f7c')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f7d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087033f04288420953f7f')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f80')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f81')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f82')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f83')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f84')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f85')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f86')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953f87')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f88')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f89')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f8a')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f8b')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f8d')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087033f04288420953f8e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953f91')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953f95')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f96')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f97')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f98')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f99')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953f9a')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f9b')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f9c')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f9d')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953f9e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953f9f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fa0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fa1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fa2')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fa3')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fa5')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fa6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fa8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fa9')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953faa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fad')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fae')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087033f04288420953faf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fb0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fb1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fb2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fb3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fb4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fb5')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953fb6')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fb7')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fb8')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953fb9')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fba')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fbb')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953fbc')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fbd')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fbe')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fbf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fc0')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953fc1')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fc2')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953fc3')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fc4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fc5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fc6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fc8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fc9')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fca')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fcb')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fcc')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fcd')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fce')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fcf')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fd0')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087033f04288420953fd1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fd2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fd3')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953fd4')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fd5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fd6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fd7')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087033f04288420953fd8')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fd9')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087033f04288420953fde')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087033f04288420953fdf')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe1')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe6')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087033f04288420953fe7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fe8')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087033f04288420953fe9')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
# ...
#  '_id': ObjectId('65a087043f0428842095952b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095952c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095952d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095952e')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f0428842095952f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959530')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959531')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959532')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959533')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959534')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959535')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087043f04288420959536')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('65a087043f04288420959537')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959538')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959539')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095953a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095953b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095953c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f0428842095953d')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f0428842095953e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095953f')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959540')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087043f04288420959541')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959542')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087043f04288420959543')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959544')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959545')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959546')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959547')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959548')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087043f04288420959549')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095954a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095954b')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095954c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095954d')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087043f0428842095954e')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f0428842095954f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959550')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959551')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087043f04288420959552')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087043f04288420959553')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959554')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087043f04288420959555')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959556')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959557')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959558')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959559')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f0428842095955a')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095955b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095955c')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095955d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095955e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095955f')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959560')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959561')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959562')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959563')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959564')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959565')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959566')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f04288420959567')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959568')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959569')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f0428842095956a')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095956b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095956c')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f0428842095956d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095956e')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f0428842095956f')}
# {'BusinessType': 'Distributors/Transporters',
#  'BusinessTypeID': 7,
#  '_id': ObjectId('65a087043f04288420959570')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959571')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959572')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f04288420959573')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959574')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959575')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087043f04288420959576')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959577')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959578')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959579')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095957a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095957b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095957c')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095957d')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095957e')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095957f')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959580')}
# {'BusinessType': 'Manufacturers/packers',
#  'BusinessTypeID': 7839,
#  '_id': ObjectId('65a087043f04288420959581')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959582')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087043f04288420959583')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959584')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087043f04288420959585')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959586')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f04288420959587')}
# {'BusinessType': 'Retailers - supermarkets/hypermarkets',
#  'BusinessTypeID': 7840,
#  '_id': ObjectId('65a087043f04288420959588')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959589')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f0428842095958a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095958b')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087043f0428842095958c')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087043f0428842095958d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095958e')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f0428842095958f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959590')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959591')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959592')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959593')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959594')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f04288420959595')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f04288420959596')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f04288420959597')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087043f04288420959598')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f04288420959599')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f0428842095959a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095959b')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f0428842095959c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f0428842095959d')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f0428842095959e')}
# {'BusinessType': 'Hotel/bed & breakfast/guest house',
#  'BusinessTypeID': 7842,
#  '_id': ObjectId('65a087043f0428842095959f')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595a0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595a1')}
# {'BusinessType': 'Mobile caterer',
#  'BusinessTypeID': 7846,
#  '_id': ObjectId('65a087043f042884209595a2')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f042884209595a3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595a4')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f042884209595a5')}
# {'BusinessType': 'Farmers/growers',
#  'BusinessTypeID': 7838,
#  '_id': ObjectId('65a087043f042884209595a6')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f042884209595a7')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f042884209595a8')}
# {'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  '_id': ObjectId('65a087043f042884209595a9')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f042884209595aa')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595ab')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f042884209595ac')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595ad')}
# {'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  '_id': ObjectId('65a087043f042884209595ae')}
# {'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  '_id': ObjectId('65a087043f042884209595af')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595b0')}
# {'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  '_id': ObjectId('65a087043f042884209595b1')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f042884209595b2')}
# {'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  '_id': ObjectId('65a087043f042884209595b3')}
# {'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  '_id': ObjectId('65a087043f042884209595b4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('65a087043f042884209595b5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {'BusinessName':'Penang Flavours'},
    {'$set':
        {'BusinessTypeID':1}
    }
)

# %%
# Confirm that the new restaurant was updated
query = {'BusinessName':'Penang Flavours'}
results = establishments.find(query)
for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65a089701ac56997b6323b84'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65a09524429a8be0e1e3bf2b'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName':'Dover'}
print(establishments.count_documents(query))
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
print(establishments.count_documents(query))
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
pprint(establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65a087033f04288420953e11'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({}, [ { '$set': { "geocode.longitude": {'$toDouble':"$geocode.longitude"},
                                           "geocode.latitude": {'$toDouble': "$geocode.latitude"}
                                           }
                                 } ] )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [ { '$set': { "RatingValue": {'$toInt':"$RatingValue"},
                                           }
                                 } ] )

# %%
# Check that the coordinates and rating value are now numbers
query = {"RatingValue": {"$gte":1}}
fields = {"geocode":1, "RatingValue":1}

results = establishments.find(query,fields)
for x in range(3):
    pprint(results[x])
# Out:
# {'RatingValue': 4,
#  '_id': ObjectId('65a087033f04288420953e11'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408}}
# {'RatingValue': 5,
#  '_id': ObjectId('65a087033f04288420953e12'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625}}
# {'RatingValue': 5,
#  '_id': ObjectId('65a087033f04288420953e14'),
#  'geocode': {'latitude': 51.085797, 'longitude': 1.194762}}
